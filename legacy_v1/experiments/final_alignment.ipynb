# %%
import sys, os
sys.path.append(os.path.join(os.path.dirname(__file__), '..'))
import torch
from src.pdclm import PDCLM, full_train

# %%
model = PDCLM(embed_dim=256)
if torch.cuda.is_available():
    model = model.cuda()

# %%
# Train with smaller settings for quick alignment demo
full_train(model, num_epochs=2, steps_per_epoch=50)
